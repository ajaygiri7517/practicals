# %% [markdown]
# Assignment No : 02
#
# Roll No : 13204
#
# Problem Statement :
#
# Creation of Dataset using Microsoft Excel.
# Identification and Handling of Outliers
# Data Transformation for the purpose of :
# a. To change the scale for better understanding
# b. To decrease the skewness and convert distribution into normal distribution

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users\/AJAY/Desktop/Student_Performance.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         72.0           84.0           76.0             90.0           456.0
# 1         62.0           82.0           65.0             87.0          2019.0
# 2         58.0           22.0            0.0             83.0          2021.0
# 3         69.0           45.0           75.0             98.0          2021.0
# 4         99.0           81.0           64.0             80.0             NaN
# 5         63.0           79.0           79.0             91.0          2021.0
# 6         68.0           78.0            0.0             92.0          2020.0
# 7         68.0           88.0           80.0             79.0            90.0
# 8          NaN           75.0           62.0             86.0          2021.0
# 9          NaN           85.0           66.0              NaN          2018.0
# 10        68.0           86.0           66.0             80.0           999.0
# ...

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count   45.000000      46.000000      47.000000        45.000000
# mean    65.844444     197.195652      82.659574        83.933333
# std     16.737214     790.976601     138.429118        19.193275
# min      0.000000       4.000000       0.000000         0.000000
# 25%     63.000000      78.000000      63.000000        80.000000
# 50%     69.000000      84.000000      67.000000        87.000000
# 75%     73.000000      91.000000      74.000000        93.000000
# max     99.000000    5444.000000     999.000000       100.000000
#
#        Club_Join_Date   Placement_Offer_Count  Club_Join_Year  Placement_Offer
# count       47.000000               46.000000        46.00000        48.000000
# mean      1829.021277                4.608696      2019.50000         2.645833
# std        643.179753               12.931406         1.41028         1.175813
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Math_Score              45 non-null     float64
#  1   Reading_Score           46 non-null     float64
#  2   Writing_Score           47 non-null     float64
#  3   Placement_Score         45 non-null     float64
#  4   Club_Join_Date          47 non-null     float64
#  5    Placement_Offer_Count  46 non-null     float64
#  6   Club_Join_Year          46 non-null     float64
#  7   Placement_Offer         48 non-null     float64
# dtypes: float64(8)
# memory usage: 3.3 KB

# %%
df.isnull().sum()
# Out:
# Math_Score                5
# Reading_Score             4
# Writing_Score             3
# Placement_Score           5
# Club_Join_Date            3
#  Placement_Offer_Count    4
# Club_Join_Year            4
# Placement_Offer           2
# dtype: int64

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count   45.000000      46.000000      47.000000        45.000000
# mean    65.844444     197.195652      82.659574        83.933333
# std     16.737214     790.976601     138.429118        19.193275
# min      0.000000       4.000000       0.000000         0.000000
# 25%     63.000000      78.000000      63.000000        80.000000
# 50%     69.000000      84.000000      67.000000        87.000000
# 75%     73.000000      91.000000      74.000000        93.000000
# max     99.000000    5444.000000     999.000000       100.000000
#
#        Club_Join_Date   Placement_Offer_Count  Club_Join_Year  Placement_Offer
# count       47.000000               46.000000        46.00000        48.000000
# mean      1829.021277                4.608696      2019.50000         2.645833
# std        643.179753               12.931406         1.41028         1.175813
# ...

# %%
df.Math_Score.max()
# Out:
# 99.0

# %%
x=df.Math_Score.mean()

# %%
df.Math_Score.fillna(x,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_19460\2143244766.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Math_Score.fillna(x,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    72.000000           84.0           76.0             90.0           456.0
# 1    62.000000           82.0           65.0             87.0          2019.0
# 2    58.000000           22.0            0.0             83.0          2021.0
# 3    69.000000           45.0           75.0             98.0          2021.0
# 4    99.000000           81.0           64.0             80.0             NaN
# 5    63.000000           79.0           79.0             91.0          2021.0
# 6    68.000000           78.0            0.0             92.0          2020.0
# 7    68.000000           88.0           80.0             79.0            90.0
# 8    65.844444           75.0           62.0             86.0          2021.0
# 9    65.844444           85.0           66.0              NaN          2018.0
# 10   68.000000           86.0           66.0             80.0           999.0
# ...

# %%
y=df.Reading_Score.mean()

# %%
df.Reading_Score.fillna(y,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_19460\3496496997.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Reading_Score.fillna(y,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    72.000000      84.000000           76.0             90.0           456.0
# 1    62.000000      82.000000           65.0             87.0          2019.0
# 2    58.000000      22.000000            0.0             83.0          2021.0
# 3    69.000000      45.000000           75.0             98.0          2021.0
# 4    99.000000      81.000000           64.0             80.0             NaN
# 5    63.000000      79.000000           79.0             91.0          2021.0
# 6    68.000000      78.000000            0.0             92.0          2020.0
# 7    68.000000      88.000000           80.0             79.0            90.0
# 8    65.844444      75.000000           62.0             86.0          2021.0
# 9    65.844444      85.000000           66.0              NaN          2018.0
# 10   68.000000      86.000000           66.0             80.0           999.0
# ...

# %%
z=df.Writing_Score.mean()

# %%
df.Writing_Score.fillna(z,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_19460\1030655535.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Writing_Score.fillna(z,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    72.000000      84.000000      76.000000             90.0           456.0
# 1    62.000000      82.000000      65.000000             87.0          2019.0
# 2    58.000000      22.000000       0.000000             83.0          2021.0
# 3    69.000000      45.000000      75.000000             98.0          2021.0
# 4    99.000000      81.000000      64.000000             80.0             NaN
# 5    63.000000      79.000000      79.000000             91.0          2021.0
# 6    68.000000      78.000000       0.000000             92.0          2020.0
# 7    68.000000      88.000000      80.000000             79.0            90.0
# 8    65.844444      75.000000      62.000000             86.0          2021.0
# 9    65.844444      85.000000      66.000000              NaN          2018.0
# 10   68.000000      86.000000      66.000000             80.0           999.0
# ...

# %%
df.iloc[11:12,3:4].fillna(34,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_19460\1705743699.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.iloc[11:12,3:4].fillna(34,inplace=True)

# %%
df.Club_Join_Year.fillna(2019,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_19460\2633519250.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Club_Join_Year.fillna(2019,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    72.000000      84.000000      76.000000             90.0           456.0
# 1    62.000000      82.000000      65.000000             87.0          2019.0
# 2    58.000000      22.000000       0.000000             83.0          2021.0
# 3    69.000000      45.000000      75.000000             98.0          2021.0
# 4    99.000000      81.000000      64.000000             80.0             NaN
# 5    63.000000      79.000000      79.000000             91.0          2021.0
# 6    68.000000      78.000000       0.000000             92.0          2020.0
# 7    68.000000      88.000000      80.000000             79.0            90.0
# 8    65.844444      75.000000      62.000000             86.0          2021.0
# 9    65.844444      85.000000      66.000000              NaN          2018.0
# 10   68.000000      86.000000      66.000000             80.0           999.0
# ...

# %%
df.Placement_Score.fillna(222,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_19460\2859260858.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_Score.fillna(222,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    72.000000      84.000000      76.000000             90.0           456.0
# 1    62.000000      82.000000      65.000000             87.0          2019.0
# 2    58.000000      22.000000       0.000000             83.0          2021.0
# 3    69.000000      45.000000      75.000000             98.0          2021.0
# 4    99.000000      81.000000      64.000000             80.0             NaN
# 5    63.000000      79.000000      79.000000             91.0          2021.0
# 6    68.000000      78.000000       0.000000             92.0          2020.0
# 7    68.000000      88.000000      80.000000             79.0            90.0
# 8    65.844444      75.000000      62.000000             86.0          2021.0
# 9    65.844444      85.000000      66.000000            222.0          2018.0
# 10   68.000000      86.000000      66.000000             80.0           999.0
# ...

# %%
df.Placement_Offer.fillna(10,inplace=True)
# Out:
# C:\Users\AJAY\AppData\Local\Temp\ipykernel_19460\2097309188.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_Offer.fillna(10,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0    72.000000      84.000000      76.000000             90.0           456.0
# 1    62.000000      82.000000      65.000000             87.0          2019.0
# 2    58.000000      22.000000       0.000000             83.0          2021.0
# 3    69.000000      45.000000      75.000000             98.0          2021.0
# 4    99.000000      81.000000      64.000000             80.0             NaN
# 5    63.000000      79.000000      79.000000             91.0          2021.0
# 6    68.000000      78.000000       0.000000             92.0          2020.0
# 7    68.000000      88.000000      80.000000             79.0            90.0
# 8    65.844444      75.000000      62.000000             86.0          2021.0
# 9    65.844444      85.000000      66.000000            222.0          2018.0
# 10   68.000000      86.000000      66.000000             80.0           999.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(7)

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join_Date', ' Placement_Offer_Count', 'Club_Join_Year',
#        'Placement_Offer'],
#       dtype='object')

# %%
col=['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
       'Club_Join_Date', ' Placement_Offer_Count', 'Club_Join_Year',
       'Placement_Offer']

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
col1=['Math_Score','Reading_Score','Writing_Score','Placement_Score']

# %%
df.boxplot(col1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
plt.scatterplot(Placement_Score,Placement_Offer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 plt.scatterplot(Placement_Score,Placement_Offer)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
fig,ax=plt.subplots(figsize=(18,10))

# %%
ax.scatter(df['Placement_Score'],df['Placement_Offer'])

# %%
plt.show()

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count   50.000000      50.000000      50.000000        50.000000
# mean    65.844444     197.195652      82.659574        97.740000
# std     15.860303     758.004621     134.124565        45.622591
# min      0.000000       4.000000       0.000000         0.000000
# 25%     64.000000      78.000000      63.250000        80.250000
# 50%     68.000000      84.500000      69.500000        88.500000
# 75%     72.750000      92.750000      76.000000        97.000000
# max     99.000000    5444.000000     999.000000       222.000000
#
#        Club_Join_Date   Placement_Offer_Count  Club_Join_Year  Placement_Offer
# count       47.000000               46.000000        50.00000        50.000000
# mean      1829.021277                4.608696      2019.46000         2.940000
# std        643.179753               12.931406         1.35842         1.856154
# ...

# %%
import numpy as np

# %%
q1=np.percentile(df.Math_Score,25)

# %%
q2=np.percentile(df.Math_Score,50)

# %%
q3=np.percentile(df.Math_Score,75)
