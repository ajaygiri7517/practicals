# %% [markdown]
# Ajay Giri
# Roll No. : 13204

# %%
print("Ajay")
# Out:
# Ajay

# %%
x=[10,20,30,40]

# %%
x.insert(2,25)

# %%
print(x)
# Out:
# [10, 20, 25, 30, 40]

# %%
p={}

# %%
print("Type of p=",type(p))
# Out:
# Type of p= <class 'dict'>

# %%
print("For Display of Empty set")
# Out:
# For Display of Empty set

# %%
p=set()

# %%
print("Empty set",p)
# Out:
# Empty set set()

# %%
print("Dictionary data")
# Out:
# Dictionary data

# %%
product={ "pid":231,"pname":'book'}

# %%
print("Data in Dictionary :",product)
# Out:
# Data in Dictionary : {'pid': 231, 'pname': 'book'}

# %%
product['price']=500

# %%
print("Data in Dictionary :",product)
# Out:
# Data in Dictionary : {'pid': 231, 'pname': 'book', 'price': 500}

# %%
a=(3, 6, 8, 10)

# %%
x=list(a)

# %%
x.append(20)

# %%
print("Data in List :",x)
# Out:
# Data in List : [3, 6, 8, 10, 20]

# %%
student={"Rollno":13204,"Name":'Ajay'}

# %%
print("Name of Student : ",student["Name"])
# Out:
# Name of Student :  Ajay
